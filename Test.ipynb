# %%
from base import Board
import matplotlib.pyplot as plt

board = Board(players=2, food=1, enemies=3)

# %%
board.show()
print(str(board))
# Out:
# Cameron: (9, 1) Nick: (2, 2)

# %%
state, score, done = board.step([(-1, -1), (0, 1)])
board.show()
state
# Out:
# ([(8, 0), (2, 3)],
#  [(5, 7), (6, 2)],
#  [(8.443745661611255, 7.116591591004518),
#   (3.254830426947662, 6.254932023735998),
#   (1.1708330760548755, 8.659935795261914)])

# %%
state, score, done = board.step([(-1, -1), (-1, -1)])
board.show()
state
# Out:
# ([(7, 0), (1, 2)],
#  [(5, 7), (6, 2), (7, 2)],
#  [(8.170782165578164, 6.46860379578219),
#   (2.8139172341141254, 5.643373286932339),
#   (0.2660286305718542, 9.394031247959406)])

# %%
state, score, done = board.step([(0, 1), (0, 1)])
board.show()
state
# Out:
# ([(7, 1), (1, 3)],
#  [(5, 7), (6, 2), (7, 2), (4, 2)],
#  [(8.821469993058633, 6.691734587700422),
#   (3.4099122298588913, 6.523580279007163),
#   (0.6072523517556174, 10.0)])

# %%
state, score, done = board.step([(0, 1), (0, 1)])
board.show()
state
# Out:
# Food found at (7, 2)
# ([(7, 2), (1, 4)],
#  [(5, 7), (6, 2), (4, 2), (0, 0)],
#  [(9.0030509462496, 6.103165681832991),
#   (2.748448311549929, 6.744575289460362),
#   (0.9250162682998941, 10.0)])

# %%
board.reset()
board.show()
